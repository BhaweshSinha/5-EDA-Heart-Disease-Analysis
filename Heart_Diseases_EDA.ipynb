# %% [markdown]
# # EDA on Heart disease dataset

# %% [markdown]
# ### Attribute Information:

# %% [raw]
# 1. Age
# 2. Sex (1= Male, 0=Female)
# 3. Cp = Chest pain type:
#     Type 0 Angina - Stable Angina
#     Type 1 Angina - Ustable Angina
#     Type 2 Angina - Variant Angina
#     Type 3 Angina - Refractory angina
# 4. Trestbps = Resting blood pressure
# 5. Chol = Serum Cholestoral in mg/dl
# 6. Fbs = fasting blood sugar > 120 mg/dl
# 7. Restecg = Resting Electrocardiographic Results:
#     Class 0 - Normal
#     Class 1 - Slightly Abnormal
#     Class 2 - Abnomal
# 8. Thalach = Maximum Heart Rate Achieved
# 9. Exang = exercise induced angina
# 10. Oldpeak =  ST depression caused by activity in comparison to rest.
# 11. Slope = Slope of the peak exercise ST Segment.
# 12. Ca = Calcium Score.
# 13. Thal = Thalassemia:
#     Value 0 - Normal
#     Value 1 - Fixed Defect
#     Value 2 - Reversable Defect
# 14. Target = Having Disease or Not:
#     Value 0 - Not Having Heart Disease
#     Value 1 - Having Heart Disease

# %% [markdown]
# ## Importing all important Libraries of Python.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Reading the CSV Dataset.

# %%
df = pd.read_csv('Heart Disease data.csv')

# %% [markdown]
# #### Showing the Dataset.

# %%
df.head()
# Out:
#    Age  Sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.tail()
# Out:
#       Age  Sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %% [markdown]
# ### Describing the Dataset:

# %%
df.describe()
# Out:
#                Age          Sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
df.shape
# Out:
# (1025, 14)

# %% [markdown]
# ### Checking the datatypes and the NULL values.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       1025 non-null   int64
#  1   Sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %% [markdown]
# #### Finding the NULL/Duplicated Values and Handling them.

# %%
df.isnull().sum()
# Out:
# Age         0
# Sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
dup = df.duplicated().any()
dup
# Out:
# True

# %%
s = df.duplicated().sum()
s
# Out:
# 723

# %%
df = df.drop_duplicates()

# %% [markdown]
# ### Showing the Dataset after removing the duplicates.

# %%
df
# Out:
#      Age  Sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     52    1   0       125   212    0        1      168      0      1.0
# 1     53    1   0       140   203    1        0      155      1      3.1
# 2     70    1   0       145   174    0        1      125      1      2.6
# 3     61    1   0       148   203    0        1      161      0      0.0
# 4     62    0   0       138   294    1        1      106      0      1.9
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 723   68    0   2       120   211    0        0      115      0      1.5
# 733   44    0   2       108   141    0        1      175      0      0.6
# 739   52    1   0       128   255    0        1      161      1      0.0
# 843   59    1   3       160   273    0        0      125      0      0.0
# 878   54    1   0       120   188    0        1      113      0      1.4
#
#      slope  ca  thal  target
# 0        2   2     3       0
# 1        0   0     3       0
# ...

# %% [markdown]
# ### Showing the correlation of attributes with each other.

# %%
df.corr()
# Out:
#                Age       Sex        cp  trestbps      chol       fbs  \
# Age       1.000000 -0.094962 -0.063107  0.283121  0.207216  0.119492
# Sex      -0.094962  1.000000 -0.051740 -0.057647 -0.195571  0.046022
# cp       -0.063107 -0.051740  1.000000  0.046486 -0.072682  0.096018
# trestbps  0.283121 -0.057647  0.046486  1.000000  0.125256  0.178125
# chol      0.207216 -0.195571 -0.072682  0.125256  1.000000  0.011428
# fbs       0.119492  0.046022  0.096018  0.178125  0.011428  1.000000
# restecg  -0.111590 -0.060351  0.041561 -0.115367 -0.147602 -0.083081
# thalach  -0.395235 -0.046439  0.293367 -0.048023 -0.005308 -0.007169
# exang     0.093216  0.143460 -0.392937  0.068526  0.064099  0.024729
# oldpeak   0.206040  0.098322 -0.146692  0.194600  0.050086  0.004514
# slope    -0.164124 -0.032990  0.116854 -0.122873  0.000417 -0.058654
# ca        0.302261  0.113060 -0.195356  0.099248  0.086878  0.144935
# thal      0.065317  0.211452 -0.160370  0.062870  0.096810 -0.032752
# ...

# %% [markdown]
# ### Showing the Heatmap of attributes with each other.

# %%
plt.figure(figsize=(20,16))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Exploring and representing the Statistics of each attributes.

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df['Sex'].value_counts()
# Out:
# Sex
# 1    206
# 0     96
# Name: count, dtype: int64

# %%
plt.pie(df['Sex'].value_counts(),labels=['Male','Female'])
plt.show()

# %%
df.value_counts(df['cp'])
# Out:
# cp
# 0    143
# 2     86
# 1     50
# 3     23
# Name: count, dtype: int64

# %%
sns.countplot(x='Sex',hue='target',data=df)
plt.xticks([1,0],['Male','Female'])
plt.legend(labels=['No-Syptoms','Symptoms'])
plt.show()

# %%
sns.displot(df['Age'],kde=True)
plt.show()

# %%
df.mean()
# Out:
# Age          54.420530
# Sex           0.682119
# cp            0.963576
# trestbps    131.602649
# chol        246.500000
# fbs           0.149007
# restecg       0.526490
# thalach     149.569536
# exang         0.327815
# oldpeak       1.043046
# slope         1.397351
# ca            0.718543
# thal          2.314570
# target        0.543046
# dtype: float64

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
sns.barplot(df,x='Sex',y=df['Age'])
plt.show()

# %% [markdown]
# Analysis of chest pain

# %%
df['cp'].value_counts()
# Out:
# cp
# 0    143
# 2     86
# 1     50
# 3     23
# Name: count, dtype: int64

# %%
sns.countplot(x='cp',data=df)
plt.show()

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df.value_counts(df['target'])
# Out:
# target
# 1    164
# 0    138
# Name: count, dtype: int64

# %%
sns.countplot(x='target',data=df)
plt.show()

# %%
sns.displot(df['cp'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(df['Age'])
plt.show()

# %%
# plt.figure(figsize=(5,10))
sns.boxplot(df['chol'])
plt.show()

# %%
sns.countplot(x='Sex',data=df)
plt.show()

# %%
df.value_counts('Sex')
# Out:
# Sex
# 1    206
# 0     96
# Name: count, dtype: int64

# %%
sns.violinplot(x=df["Age"])
# Out:
# <Axes: xlabel='Age'>

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
sns.scatterplot(x="Age",y='chol',data=df)
plt.show()

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
sns.scatterplot(x='Age',y='Sex',data=df)
plt.show()

# %%
sns.scatterplot(x="target",y='thalach',data=df)
plt.show()

# %% [markdown]
# ### Showing the pairplot.

# %%
sns.pairplot(df)
plt.figure(figsize=(500,500))
plt.show()
